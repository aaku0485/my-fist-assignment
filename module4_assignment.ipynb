# %% [markdown]
# <a href="https://colab.research.google.com/github/aaku0485/my-fist-assignment/blob/main/module4_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Q1 - Discuss string slicing and provide examples .

ans - String slicing is a way to get a specific part or element of a string by using [start:end:step] values .It's especially useful for
text manipulation and data parsing .'''

s = "hello"
s[0:3:1] #we used the slice s[0:3] to obtain the substring from string
#here s is an original string and the start index always start with 0 index(inclusive) whwere as
#end - end index is on user where, user wants to stop
#step - index of the string runs 1 by 1 from left to right .
s[::1] # here , if we can't give the value of start and end then the string will be printed from start to end
s[0:-1] # here, string has negative value running from indexing from left to right .
s[::] # here without using start end and step returns the complete string.
s1 = "aapse mil ke accha laga"
s1[2::2] # the slice[2::2] starts with index 2 and continues to last index with step index of 2
s1[::-1]# printing the index from the right to left / reversing
s1[3:-1:2] # getting each index from third elements to excluding -1 index.

'''Q2 - Explain the key features of list in Python .

ans - A list is an in built data type structure that is used to store an ordered collection of items . we can create a list by using [].
key features of list are :
1 - list is a mutable type where we can access and change the data of list .
2 - the list are in order and the element of order starts from 0.
3 - list can store element of different data types , such as integers , float, another list.
4 - we can use indexing and slicing in list just as string [ start:end:step].
5 - as list is mutable we can use many built in function such as . append, .pop, .insert, sort(), count(),reverse().
6 - lists can also contains another list .
7 - we can use list to itirate in the loop .
'''
#accessing of element
list1 =[1, "aaple",2.34,True,[1,2,3]]
list1[1]
list1[-1]

#Modification of list
list1.append("aakash")
print(list1)
#changing element of list
list1[1] = 69
print(list1)
#iterartion over loops
for item in list1:
  print(item)
#removing element
list1.pop(2)
del list1[0]
print(list1)

'''Q3- Describe how to access , modify, and delete elements from list.

ans - List is mutuable type data structure, where we can access, modify the elements the elements of list with using some specific function.'''

my_list = [1,2,3.5, True, "apple", [2,3,5]]
my_list[0] # accessing of element
my_list[2:4]# accessing index from 2 to 4
my_list[::]# printing index from statting to ending
#MODIFICATION OF ELEMENTS IN LIST
my_list.append("aayaush_pagla")
my_list.append("aayush batah")

my_list.pop(2)
del my_list[5]
print(my_list)

'''Q4 - compare and contrast tuples and lists with examples.

ans - list and tuples both are created both to store data but they have key diffrences in their properties:
Mutability - lists are mutable and their elements can be changed after they crested but whereas tuples are not mutuable so their element can't be changed.
'''
list1 = [1,2,3,4,5]
list1[1] = 88

tuple1 = (1,2,3,4)
#tuple1(3) = 89  # it will show error.

'''Syntax - list is defined with [] whereas tuples is defined as ()
ex - list = [1,2,3,4]
tuples =(1,2,3,4)

Use Cases - list are suitable for collection that need to be modified frequently such as adding and removing items are they  created
tuples are used for collection of data that should remain constant .

performance - lists are slower due to overhead of mutability whereas tuples are faster than list because they are immutable and require less memory.

Method - lists due to mutability it provide a wide range of inbuilt function such as: .append(), .pop(),.extend(),.remove()
whereas lists tuples provide fewer count and index for mirroring .
EX - list1 =[1 ,2 , 3.5, True , [2,4,6]]
list1.append("aakash") # adds the element in list
tuple1 = (1,2,3,4,1)
print(tuple1.count(1)) #count occurrences of 1

Q5 - Describe the keyfetures of of sets and provide the example of their uses .

Ans - sets are a collection of data type that store unique elements . They are particularly useful for opertaions involving membership,
deduplication and mathematical set operations .

key features of sets are :
1 - unodered : sets do not maintain the order of elements . there is no way to access the element by indexing or slicing.
2- Unique element : a set is automaticallly removes the duplicate elements.
3 - Mutable: sts can be modified after creation
4 - sets provides a frozenset in python wich is an immutable version of set
5 - hetrogeneous - sets can contain elements of different data types , as long as they ar hasable .
6 - dynamic  : sets can grow and shrink dynamically as element are added or removed .
7 - no duplicates : automatically enforces uniqueness of element .
8 - supports mathematical operators including operations like union , intersection , differences and symmetric differences .
9 - supporting built in functions such as .pop(), .append() , .discard(), .remove() , .clear(), union() , intersection(), differences().'''
set1 = {1,2,3,"aakash","potato","mango"} #creating set
set1.add(4) #adding 4 in a set
set1.remove(1) # removing element 1
set1.discard(8) #.discard is used for not printing error if the element is not missing .
print(2 in set1) # gives the result in True or False
print(8 in set1)
print(set1)
setA = {1,2,3}
setB = {4,5,6}
print(setA | setB) # UNION OF SETA AND SETB
print(setA & setB) # INTERSECTION {3}
print(setA - setB) #substraction
print(setA ^ setB)


'''Q6 - Discuss the use case of tuples and sets in python programming.

ans - Tuples are ordered collection of elments and heterogeneous data structure that stores element in colums of single row or multiple row
and  it is an immutable data storage , indicated by parenthesis().
it used for storing that can't be change like personal information , personal data
ex: storing personal data of a person ,'''
person = ("aakash", 24, "patna")
print(person[0])  #name of person
print(person[1])  #age
print(person[2])  #address

#storing product details
product = ("iphone 14" , 65000 , 5)
print(product[0]) #product
print(product[1]) # value of product
print(product[2]) # number of product
''' whereas sets are the unordered collection of unique elements, it means each element can only appears in the sets only one time .
It is define as {} , it is mutable and iterates with loop.
use case :
sets are used for removing the duplicate elements.
Efficiently check if an element exists in a collection.
It performs mathematical operations like union, interaction, difference nd symetric in sets.
extracting unique element from sequence while preserving order.
data cleansing and preproccessing .'''
list1 = [1,2,3,4,3,2,5,6,1,7,8]
unique_element = set(list1)
print(unique_element) # output{1,2,3,4,5,6,7,8}

set2 = {1,2,3,4,5,6}
if 2 and 3 in set2:
  print("2and 3 is in the set")

  list2 = [1,2,3,4,5,4,3,2,6,7,9,7]
  unique_list = list(set(list2))
  print(unique_list)

  '''Q7. Describe how to add , modify , and delete items in dictionary with example.

  ans. Dictonaries in python are mutable , where we can easily add , modify , del , the items after the creation.
  Ex -'''
  #addition of items in dictionary
  my_dict ={"name": "aakash", "age ": 24}
  my_dict["city"] = "patna"
  print(my_dict)

  #modifying of an item in dictionary
  dic = {"name" : "aakash","age" :24}
  dic["age"] = 25
  print(dic)

  #deleting of an item
  dic2 = {"name":"aakash","age":24,"city":"patna"}
  del dic2["city"]
  print(dic2)

  #popping out an item
  dic3 = {"name": "aakash","age": 24, "city": "patna"}
  city1 = dic3.pop("city")
  print(dic3)
  print(city1)

  '''Q7- Discuss the importance of dictionary keys of being immutable and provide example.

  ans - In Python dictonaries are unordered coolection of keys value pairs . A crucial characteristic of dictionary keys is that they must be immutable.
     keys in dictionaries are immutable because dictonaries usevkeys to determine the storage and retrieveal of values .
     immutable keys ensure the intergrity of dictionary 's internal structure . if keys were mutable then the values could be change
     which could leading to inconsistencies in the dictionary . Immutable keys also provide a  reliable and efficient way to hash and
     compare values values ensuring fast lookups and operation . by enforcing immutability , dictionaties gurantee the the stability and
     predictablity of their key values pairs , making them a fundamental data structure for efficient mapping and retrevel of information.
     ex - '''
employee = {"name": "aakash", "age": 20}
     # extract the dictionary keys
dictionaryKeys = employee.keys()
print('Before dictionary update: ', dictionarykeys)

     #add an element to the dictionary
employee.update({"salary":3500.0})

     #print the updated view object
print("after dictionary update :, dictionarykeys")
# Out:
# [1, 'aaple', 2.34, True, [1, 2, 3], 'aakash']
# [1, 69, 2.34, True, [1, 2, 3], 'aakash']
# 1
# 69
# 2.34
# True
# [1, 2, 3]
# aakash
# [69, True, [1, 2, 3], 'aakash']
# [1, 2, True, 'apple', [2, 3, 5], 'aayush batah']
# True
# False
# {2, 3, 'aakash', 4, 'mango', 'potato'}
# {1, 2, 3, 4, 5, 6}
# set()
# {1, 2, 3}
# {1, 2, 3, 4, 5, 6}
# aakash
# 24
# patna
# iphone 14
# 65000
# 5
# {1, 2, 3, 4, 5, 6, 7, 8}
# 2and 3 is in the set
# [1, 2, 3, 4, 5, 6, 7, 9]
# {'name': 'aakash', 'age ': 24, 'city': 'patna'}
# {'name': 'aakash', 'age': 25}
# {'name': 'aakash', 'age': 24}
# {'name': 'aakash', 'age': 24}
# patna
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-368eb056b2e3> in <cell line: 196>()
#     194      # extract the dictionary keys
#     195 dictionaryKeys = employee.keys()
# --> 196 print('Before dictionary update: ', dictionarykeys)
#     197
# ...
